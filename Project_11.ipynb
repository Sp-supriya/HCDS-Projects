# %% [markdown]
# <a href="https://colab.research.google.com/github/Sp-supriya/HCDS-Projects/blob/main/Project_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Create customer satisfaction survey dashboard**

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.9/33.9 MB 21.7 MB/s eta 0:00:00
# ...

# %%
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd


url = 'https://docs.google.com/spreadsheets/d/1CYHwKlcIbnFQ9KfVy-UlbZpfY5apx9Fp-r3-YhVBig4/export?format=csv'

df = pd.read_csv(url)

df.head()  # Show first few rows
# Out:
#              Timestamp    Name                   Email    \
# 0  05/05/2025 15:21:22  supriya  supriyasp1504@gmail.com
#
#      How satisfied are you with our service?    \
# 0                                            4
#
#      What did you like or dislike about the service?    \
# 0                                                NaN
#
#     Would you recommend us to others?     Date of Visit or Interaction
# 0                                   Yes                       02/05/2025

# %%
print(df.columns.tolist())
# Out:
# ['Timestamp', 'Name ', '  Email  ', '  How satisfied are you with our service?  ', '  What did you like or dislike about the service?  ', '  Would you recommend us to others?  ', '  Date of Visit or Interaction  ']

# %%
['Timestamp', 'Rate our service (1–5)', 'How was your experience?']
# Out:
# ['Timestamp', 'Rate our service (1–5)', 'How was your experience?']

# %%
df.columns = df.columns.str.strip()

# %%
df.columns = df.columns.str.strip()
df.columns = df.columns.str.replace('\u2013', '-', regex=True)  # Replace en dash with regular dash
df.columns = df.columns.str.replace('\xa0', ' ', regex=True)    # Replace non-breaking space if present
print(df.columns.tolist())  # Confirm cleaned column names
# Out:
# ['Timestamp', 'Name', 'Email', 'How satisfied are you with our service?', 'What did you like or dislike about the service?', 'Would you recommend us to others?', 'Date of Visit or Interaction']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6396863a-3341-4a2a-81b3-14d76c780616" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6396863a-3341-4a2a-81b3-14d76c780616">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Replace with your actual file path or data source
df = pd.read_csv("sample_customer_satisfaction.csv")
df.head()
# Out:
#    CustomerID  Age  Gender  Satisfaction  EaseOfUse  SupportQuality  \
# 0         101   25    Male             4          4               5
# 1         102   34  Female             5          5               5
# 2         103   45  Female             3          3               3
# 3         104   29    Male             2          2               2
# 4         105   40    Male             4          4               3
#
#                          Comments
# 0  Great service and easy to use.
# 1         Loved the support team!
# 2   It was okay, could be better.
# 3         Too slow and confusing.
# 4              Satisfied overall.

# %%
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      5 non-null      int64
#  1   Age             5 non-null      int64
#  2   Gender          5 non-null      object
#  3   Satisfaction    5 non-null      int64
#  4   EaseOfUse       5 non-null      int64
#  5   SupportQuality  5 non-null      int64
#  6   Comments        5 non-null      object
# dtypes: int64(5), object(2)
# memory usage: 412.0+ bytes
#         CustomerID        Age Gender  Satisfaction  EaseOfUse  SupportQuality  \
# count     5.000000   5.000000      5      5.000000   5.000000        5.000000
# unique         NaN        NaN      2           NaN        NaN             NaN
# top            NaN        NaN   Male           NaN        NaN             NaN
# freq           NaN        NaN      3           NaN        NaN             NaN
# ...

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x="Satisfaction", data=df, palette="coolwarm")
plt.title("Customer Satisfaction Distribution")
plt.xlabel("Satisfaction Rating")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-6-a5bdfaf2e311>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Satisfaction", data=df, palette="coolwarm")

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Gender", y="Satisfaction", data=df, palette="pastel")
plt.title("Satisfaction by Gender")
plt.show()
# Out:
# <ipython-input-7-0e93835500a5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Gender", y="Satisfaction", data=df, palette="pastel")

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Between Survey Metrics")
plt.show()
